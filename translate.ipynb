# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-zh-en")

model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-zh-en")

# %%
import shap

data = ["中国空间站的建造比国际空间站晚20多年。"]
# we build an explainer by passing the model we want to explain and
# the tokenizer we want to use to break up the input strings
explainer = shap.Explainer(model, tokenizer)

# explainers are callable, just like models
shap_values = explainer(data, fixed_context=1)
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_ycrlmiaomapklckknaxu = '_tp_ycrlmiaomapklckknaxu_output_0';
#     document._zoom_ycrlmiaomapklckknaxu = undefined;
#     function _output_onclick_ycrlmiaomapklckknaxu(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ycrlmiaomapklckknaxu !== undefined) {
#             document.getElementById(document._zoom_ycrlmiaomapklckknaxu+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ycrlmiaomapklckknaxu === '_tp_ycrlmiaomapklckknaxu_output_' + i) {
#                 document.getElementById(document._zoom_ycrlmiaomapklckknaxu).style.display = 'block';
#                 document.getElementById(document._zoom_ycrlmiaomapklckknaxu+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ycrlmiaomapklckknaxu).style.display = 'none';
#                 document.getElementById(document._zoom_ycrlmiaomapklckknaxu+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ycrlmiaomapklckknaxu !== '_tp_ycrlmiaomapklckknaxu_output_' + i) {
#             next_id = '_tp_ycrlmiaomapklckknaxu_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ycrlmiaomapklckknaxu = next_id;
#     }
#     function _output_onmouseover_ycrlmiaomapklckknaxu(i, el) {
#         if (document._zoom_ycrlmiaomapklckknaxu !== undefined) { return; }
#         if (document._hover_ycrlmiaomapklckknaxu !== undefined) {
#             document.getElementById(document._hover_ycrlmiaomapklckknaxu + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ycrlmiaomapklckknaxu).style.display = 'none';
#         }
#         document.getElementById('_tp_ycrlmiaomapklckknaxu_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ycrlmiaomapklckknaxu = '_tp_ycrlmiaomapklckknaxu_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.05407011289364222); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_0_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(0)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(0, this);">The</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.022539116656763607); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_1_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(1)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(1, this);">construction</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.7241037829273124); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_2_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(2)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(2, this);">of</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.3142008318478907); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_3_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(3)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(3, this);">the</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.05407011289364243); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_4_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(4)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(4, this);">Chinese</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.1959595959595959); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_5_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(5)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(5, this);">space</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.7950485244602892); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_6_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(6)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(6, this);">station</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.12501485442661905); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_7_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(7)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(7, this);">was</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_8_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(8)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(8, this);">more</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.77928302634185); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_9_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(9)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(9, this);">than</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.5585660526836996); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_10_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(10)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(10, this);">20</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_11_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(11)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(11, this);">years</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.014656367597544035); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_12_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(12)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(12, this);">later</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.7714002772826303); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_13_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(13)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(13, this);">than</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.25902158843335304); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_14_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(14)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(14, this);">that</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.6137452960982372); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_15_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(15)"
#     onmouseover="_output_onmouseover_ycrlmiaomapklckknaxu(15, this);">of</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.49550406020994264); border-radius: 3px; padding: 0px" id="_tp_ycrlmiaomapklckknaxu_output_16_name"
#     onclick="_output_onclick_ycrlmiaomapklckknaxu(16)"
#     onmouseover="_output_on
